# %%
# Módulos numéricos y de funciones científicas
import numpy as np
from scipy import signal as sig
import sympy as sp
from IPython.display import display, Math

# Módulos para los gráficos
import matplotlib as mpl
from matplotlib import pyplot as plt

# Funciones de PyTC2
from pytc2.sistemas_lineales import bodePlot, pzmap, GroupDelay, analyze_sys, tf2sos_analog, pretty_print_SOS
from pytc2.general import print_latex, print_subtitle, a_equal_b_latex_s

#Tamaño de los gráficos
fig_sz_x = 13
fig_sz_y = 7
fig_dpi = 80 # dpi

fig_font_size = 11

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

# %%
eps2=10**(1/10) - 1

frac=np.array([1,0,3/2,0,9/16,0,-1/(16*eps2)])
frac=np.round(frac,4)

print(frac[6])

raices=np.roots(frac)
raices=raices[np.real(raices)<0]

s = sp.symbols('s')

coeff=np.poly(raices)
#print(coeff)
coeff=np.round(coeff,4)

den=sp.Poly(coeff,s)
display(Math(sp.latex(den)))
# Out:
# -0.2414
# $\displaystyle \operatorname{Poly}{\left( 1.0 s^{3} + 0.9884 s^{2} + 1.2384 s + 0.4913, s, domain=\mathbb{R} \right)}$

# %%
num,den = sig.cheby1(3,1,1, analog=True)
print(num)
# Out:
# [0.49130668]

# %%
numhp, denhp = sig.lp2hp(num,den)
numhp=np.round(numhp,4)
denhp=np.round(denhp,4)
numhp_pol = sp.Poly(numhp,s)
denhp_pol = sp.Poly(denhp,s)

Tsbp=sp.simplify(numhp_pol)/sp.simplify(denhp_pol)

display(Math(r'T(s) = ' + sp.latex(Tsbp)))
sospb = tf2sos_analog(numhp, denhp)

print_latex(a_equal_b_latex_s('T_{bp}(s)', pretty_print_SOS(sospb, displaystr=False)))
# Out:
# $\displaystyle T(s) = \frac{1.0 s^{3}}{1.0 s^{3} + 2.5206 s^{2} + 2.0117 s + 2.0354}$
# $\displaystyle T_{bp}(s)= \frac{s \,\,   1 }{s + 2.024 } . \frac{s^2 \,\,   1 }{s^2 + s \,\, 0.4971 + 1.006 }$
